# %%
import pandas as pd

# %%
df_green_2015 = pd.read_parquet('data/raw_nyc_taxi_data_green_taxi_data_green_tripdata_2015-11.parquet', engine='pyarrow')
df_green_2015_10 = pd.read_parquet('data/raw_nyc_taxi_data_green_taxi_data_green_tripdata_2015-10.parquet', engine='pyarrow')

# %%
df_green_2015.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2015-11-01 00:10:24   2015-11-01 00:14:14                  N
# 1         2  2015-11-01 00:18:16   2015-11-01 00:25:12                  N
# 2         2  2015-11-01 00:30:38   2015-11-01 01:01:17                  N
# 3         1  2015-11-01 00:04:32   2015-11-01 00:40:29                  N
# 4         2  2015-11-01 00:42:19   2015-11-01 00:42:23                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0           1           112           255                1           1.00
# 1           1           112           112                1           0.56
# 2           1           112           148                1           3.98
# 3           1           188           230                1          10.00
# 4           5            76            76                1           0.00
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount ehail_fee  \
# ...

# %%
df_green_2015_10.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2015-10-01 00:38:37   2015-10-01 00:38:41                  N
# 1         2  2015-10-01 00:39:30   2015-10-01 00:39:33                  N
# 2         2  2015-10-01 00:04:54   2015-10-01 00:10:38                  N
# 3         2  2015-10-01 00:26:17   2015-10-01 00:40:50                  N
# 4         2  2015-10-01 00:53:39   2015-10-01 00:59:54                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0           1           193           193                1           0.00
# 1           1           193           193                1           0.00
# 2           1           255           256                1           0.87
# 3           1           255            61                1           3.49
# 4           1           181            49                1           1.26
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount ehail_fee  \
# ...

# %%
df_green_2015['trip_type'].isnull().sum()
df_green_2015['trip_type'] = df_green_2015['trip_type'].astype('float64')

# %%
df_green_2015.to_parquet('data/green_tripdata_2015-11.parquet', engine='pyarrow')

# %%
df_green_2015_processed = pd.read_parquet('data/green_tripdata_2015-11.parquet', engine='pyarrow')
df_green_2015_processed.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2015-11-01 00:10:24   2015-11-01 00:14:14                  N
# 1         2  2015-11-01 00:18:16   2015-11-01 00:25:12                  N
# 2         2  2015-11-01 00:30:38   2015-11-01 01:01:17                  N
# 3         1  2015-11-01 00:04:32   2015-11-01 00:40:29                  N
# 4         2  2015-11-01 00:42:19   2015-11-01 00:42:23                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0           1           112           255                1           1.00
# 1           1           112           112                1           0.56
# 2           1           112           148                1           3.98
# 3           1           188           230                1          10.00
# 4           5            76            76                1           0.00
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount ehail_fee  \
# ...
